# %%
import urllib.request
import os
import re
import random
import string
import time

def url_open(url):
    req = urllib.request.Request(url)
    req.add_header('User-Agent','Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:36.0) Gecko/20100101 Firefox/36.0')
    response = urllib.request.urlopen(req,timeout=60)
    return response.read()

# 获取page页码 1........9
def get_page_id_arr(url):
    html = url_open(url).decode('utf-8')
#     print(html)
    pattern = r'href="([^"]*page=[0-9]{0,2})"[^>]*>.+?' # 匹配href
    page_id_arr = re.findall(pattern, html)
    page_id_arr_enable = []  # 过滤不需要的链接
    for id in page_id_arr:
        idstr = str(id)
        if idstr.find('page=') != -1 : #筛选页码地址
            page_id_arr_enable.append(idstr)
    print("页面所有pageId", page_id_arr_enable)
    return page_id_arr_enable

# 获取某页PAGEID中的所有相册链接地址
def find_all_album_of_page(page_url):
    print("当前页面地址", page_url)
    pattern = r'href="([^"]*id=[0-9]{2,10})"[^>]*>.+?' # 匹配href
    html = url_open(page_url).decode('utf-8')
    alllinks = re.findall(pattern,html)
    print("页面所有相册链接地址：" , alllinks)
    return alllinks

# 进入某个相册获取所有图片链接
def get_down_all_pic_of_album(folder, album_url):
    pattern = r'src="([^"]*[0-9]{1,5}/[0-9]{2,7}-[0-9]{1,2}.jpg)"' # 匹配图片src地址
    html = url_open(album_url).decode('utf-8')
    img_addrs = re.findall(pattern, html)
    #https://img.yituyu.com/gallery/1070/00_qUYWQyHT.jpg
    img_addrs_enable = [] # 过滤不需要的链接
    for h in img_addrs : 
        x = str(h)
        if x.find("tutu.94zzh.com") != -1 :
            img_addrs_enable.append(x)
    print(album_url + "页面所有图片下载地址：" , img_addrs_enable)
    # 下载此页面的所有图片
    album_name = str(album_url)
    save_imgs(folder,img_addrs_enable, album_name) 
    print("暂停十秒获取下一个相册")
    time.sleep(10) #暂停一秒
    
# 保存图片到文件夹
def save_imgs(folder, img_addrs, album_name):
    sub_dir = album_name.replace("/","").replace(":","").replace(".","").replace("?","").replace("&","").replace("=","")
    os.chdir(folder)
    dirname = sub_dir
    makeDir(dirname)
    os.chdir(dirname)
    for i in img_addrs:
        pic_down_link = str(i)
#         file_name_str = pic_down_link.split('/')
#         filename = file_name_str[-1] # 文件名称 
#         ranInt = ''.join(random.sample(string.ascii_letters + string.digits, 8))# 使用随机数
        filename = pic_down_link.replace("/","").replace(":","")
        pic_pre = "" # 图片下载前缀
        real_down_url = pic_pre + pic_down_link
#       print("图片下载地址", real_down_url)
        image = url_open(real_down_url)
#       print("文件名：" + filename)
        with open(filename,'wb') as f:
            f.write(image)
            f.close()
            print("图片下载完成", real_down_url)
            time.sleep(1) #暂停一秒

# 创建文件夹
def makeDir(folder):
    if os.path.exists(folder) :
        print(folder + "文件夹已存在")
        pass
    try:
        os.mkdir(folder)
    except OSError:
        pass

def download_some(folder='ooxx',pages=10):
    current_dir = "D:\GitHubProject\jupyter-notebook\AllMyTest\\downLoad\\www.a8e0e744fa9b81a7.com\\"
    makeDir(current_dir)
    folder = current_dir + folder
    print("文件存储文件夹：",folder)
    makeDir(folder) #新建文件夹
    os.chdir(folder) #跳转到文件夹
    folder_top = os.getcwd() #获取当前工作目录
    url = 'https://www.a8e0e744fa9b81a7.com/piclist.x?classid=7'
    page_id_arr = get_page_id_arr(url) #获取网页中的pageId
    for page_id in page_id_arr:
        page_url_pre = "https://www.a8e0e744fa9b81a7.com/piclist.x" # page前缀
        page_url = page_url_pre + page_id #组合page访问地址
        all_album_link_arr = find_all_album_of_page(page_url) #获取PageId相册地址
        # 进入页面找到播放地址
        for album_link in all_album_link_arr:
            # 图片服务器可能和访问服务器不是一个,需要组合
            album_pre = "https://www.a8e0e744fa9b81a7.com"
            real_album_link = album_pre + album_link
            # 进入页面下载此页面所有图片
            get_down_all_pic_of_album(folder, real_album_link)
        print("暂停十秒获取下一页")
        time.sleep(10) #暂停一秒
            

if __name__ == '__main__':
    folder = input("下载到哪里？(default is 'ooxx'): " )
    pages  = input("下载多少页？(default is 10): ")
    download_some(str(folder),int(pages))
# Out:
# 下载到哪里？(default is 'ooxx'): madeya
# 下载多少页？(default is 10): 2
# D:\GitHubProject\jupyter-notebook\AllMyTest\downLoad\www.a8e0e744fa9b81a7.com\文件夹已存在
# 文件存储文件夹： D:\GitHubProject\jupyter-notebook\AllMyTest\downLoad\www.a8e0e744fa9b81a7.com\madeya
# 页面所有pageId ['?classid=7&page=2', '?classid=7&page=3', '?classid=7&page=4', '?classid=7&page=5', '?classid=7&page=6', '?classid=7&page=7', '?classid=7&page=8', '?classid=7&page=9', '?classid=7&page=2']
# 当前页面地址 https://www.a8e0e744fa9b81a7.com/piclist.x?classid=7&page=2
# 页面所有相册链接地址： ['/pn.x?stype=pic&id=185854', '/pn.x?stype=pic&id=185853', '/pn.x?stype=pic&id=185852', '/pn.x?stype=pic&id=185851', '/pn.x?stype=pic&id=185850', '/pn.x?stype=pic&id=185849', '/pn.x?stype=pic&id=185848', '/pn.x?stype=pic&id=185847', '/pn.x?stype=pic&id=185846', '/pn.x?stype=pic&id=185845', '/pn.x?stype=pic&id=185844', '/pn.x?stype=pic&id=185843', '/pn.x?stype=pic&id=185842', '/pn.x?stype=pic&id=185841', '/pn.x?stype=pic&id=185725', '/pn.x?stype=pic&id=185724', '/pn.x?stype=pic&id=185723', '/pn.x?stype=pic&id=185722', '/pn.x?stype=pic&id=185721', '/pn.x?stype=pic&id=185720', '/pn.x?stype=pic&id=185719', '/pn.x?stype=pic&id=185718', '/pn.x?stype=pic&id=185717', '/pn.x?stype=pic&id=185716', '/pn.x?stype=pic&id=185715', '/pn.x?stype=pic&id=185610', '/pn.x?stype=pic&id=185493', '/pn.x?stype=pic&id=185492', '/pn.x?stype=pic&id=185491', '/pn.x?stype=pic&id=185490']
# https://www.a8e0e744fa9b81a7.com/pn.x?stype=pic&id=185854页面所有图片下载地址： ['https://tutu.94zzh.com/d9/4278/427866-1.jpg', 'https://tutu.94zzh.com/d9/4278/427866-2.jpg', 'https://tutu.94zzh.com/d9/4278/427866-3.jpg', 'https://tutu.94zzh.com/d9/4278/427866-4.jpg', 'https://tutu.94zzh.com/d9/4278/427866-5.jpg', 'https://tutu.94zzh.com/d9/4278/427866-6.jpg', 'https://tutu.94zzh.com/d9/4278/427866-7.jpg', 'https://tutu.94zzh.com/d9/4278/427866-8.jpg', 'https://tutu.94zzh.com/d9/4278/427866-9.jpg', 'https://tutu.94zzh.com/d9/4278/427866-10.jpg', 'https://tutu.94zzh.com/d9/4278/427866-11.jpg', 'https://tutu.94zzh.com/d9/4278/427866-12.jpg', 'https://tutu.94zzh.com/d9/4278/427866-13.jpg', 'https://tutu.94zzh.com/d9/4278/427866-14.jpg', 'https://tutu.94zzh.com/d9/4278/427866-15.jpg', 'https://tutu.94zzh.com/d9/4278/427866-16.jpg', 'https://tutu.94zzh.com/d9/4278/427866-17.jpg', 'https://tutu.94zzh.com/d9/4278/427866-18.jpg', 'https://tutu.94zzh.com/d9/4278/427866-19.jpg', 'https://tutu.94zzh.com/d9/4278/427866-20.jpg', 'https://tutu.94zzh.com/d9/4278/427866-21.jpg', 'https://tutu.94zzh.com/d9/4278/427866-22.jpg', 'https://tutu.94zzh.com/d9/4278/427866-23.jpg', 'https://tutu.94zzh.com/d9/4278/427866-24.jpg', 'https://tutu.94zzh.com/d9/4278/427866-25.jpg', 'https://tutu.94zzh.com/d9/4278/427866-26.jpg', 'https://tutu.94zzh.com/d9/4278/427866-27.jpg', 'https://tutu.94zzh.com/d9/4278/427866-28.jpg', 'https://tutu.94zzh.com/d9/4278/427866-29.jpg', 'https://tutu.94zzh.com/d9/4278/427866-30.jpg', 'https://tutu.94zzh.com/d9/4278/427866-31.jpg', 'https://tutu.94zzh.com/d9/4278/427866-32.jpg', 'https://tutu.94zzh.com/d9/4278/427866-33.jpg', 'https://tutu.94zzh.com/d9/4278/427866-34.jpg', 'https://tutu.94zzh.com/d9/4278/427866-35.jpg', 'https://tutu.94zzh.com/d9/4278/427866-36.jpg', 'https://tutu.94zzh.com/d9/4278/427866-37.jpg']
# 图片下载完成 https://tutu.94zzh.com/d9/4278/427866-1.jpg
# 图片下载完成 https://tutu.94zzh.com/d9/4278/427866-2.jpg
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# c:\users\admin\appdata\local\programs\python\python38\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             try:
# -> 1319                 h.request(req.get_method(), req.selector, req.data, headers,
#    1320                           encode_chunked=req.has_header('Transfer-encoding'))
#
# c:\users\admin\appdata\local\programs\python\python38\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1229         """Send a complete request to the server."""
# -> 1230         self._send_request(method, url, body, headers, encode_chunked)
#    1231
#
# c:\users\admin\appdata\local\programs\python\python38\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1275             body = _encode(body, 'body')
# -> 1276         self.endheaders(body, encode_chunked=encode_chunked)
#    1277
#
# c:\users\admin\appdata\local\programs\python\python38\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1224             raise CannotSendHeader()
# -> 1225         self._send_output(message_body, encode_chunked=encode_chunked)
#    1226
#
# c:\users\admin\appdata\local\programs\python\python38\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1003         del self._buffer[:]
# -> 1004         self.send(msg)
#    1005
#
# c:\users\admin\appdata\local\programs\python\python38\lib\http\client.py in send(self, data)
#     943             if self.auto_open:
# --> 944                 self.connect()
#     945             else:
#
# c:\users\admin\appdata\local\programs\python\python38\lib\http\client.py in connect(self)
#    1398
# -> 1399             self.sock = self._context.wrap_socket(self.sock,
#    1400                                                   server_hostname=server_hostname)
#
# c:\users\admin\appdata\local\programs\python\python38\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# c:\users\admin\appdata\local\programs\python\python38\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# c:\users\admin\appdata\local\programs\python\python38\lib\ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# timeout: _ssl.c:1091: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-7-1ca5d61930c0> in <module>
#     115     folder = input("下载到哪里？(default is 'ooxx'): " )
#     116     pages  = input("下载多少页？(default is 10): ")
# --> 117     download_some(str(folder),int(pages))
#     118
#
# <ipython-input-7-1ca5d61930c0> in download_some(folder, pages)
#     107             real_album_link = album_pre + album_link
#     108             # 进入页面下载此页面所有图片
# --> 109             get_down_all_pic_of_album(folder, real_album_link)
#     110         print("暂停十秒获取下一页")
#     111         time.sleep(10) #暂停一秒
#
# <ipython-input-7-1ca5d61930c0> in get_down_all_pic_of_album(folder, album_url)
#      49     # 下载此页面的所有图片
#      50     album_name = str(album_url)
# ---> 51     save_imgs(folder,img_addrs_enable, album_name)
#      52     print("暂停十秒获取下一个相册")
#      53     time.sleep(10) #暂停一秒
#
# <ipython-input-7-1ca5d61930c0> in save_imgs(folder, img_addrs, album_name)
#      69         real_down_url = pic_pre + pic_down_link
#      70 #       print("图片下载地址", real_down_url)
# ---> 71         image = url_open(real_down_url)
#      72 #       print("文件名：" + filename)
#      73         with open(filename,'wb') as f:
#
# <ipython-input-7-1ca5d61930c0> in url_open(url)
#       9     req = urllib.request.Request(url)
#      10     req.add_header('User-Agent','Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:36.0) Gecko/20100101 Firefox/36.0')
# ---> 11     response = urllib.request.urlopen(req,timeout=90)
#      12     return response.read()
#      13
#
# c:\users\admin\appdata\local\programs\python\python38\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\users\admin\appdata\local\programs\python\python38\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# c:\users\admin\appdata\local\programs\python\python38\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# c:\users\admin\appdata\local\programs\python\python38\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# c:\users\admin\appdata\local\programs\python\python38\lib\urllib\request.py in https_open(self, req)
#    1360
#    1361         def https_open(self, req):
# -> 1362             return self.do_open(http.client.HTTPSConnection, req,
#    1363                 context=self._context, check_hostname=self._check_hostname)
#    1364
#
# c:\users\admin\appdata\local\programs\python\python38\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1320                           encode_chunked=req.has_header('Transfer-encoding'))
#    1321             except OSError as err: # timeout error
# -> 1322                 raise URLError(err)
#    1323             r = h.getresponse()
#    1324         except:
#
# URLError: <urlopen error _ssl.c:1091: The handshake operation timed out>

# %%
import re

html = '<a href="/tag/qiaotun/index_2.html">2</a>'
pattern = r'href="([^"]*)"[^>]*>.+?' # 匹配href
print(re.findall(pattern,html))
pattern2 = r'src="([^"]*)"+?'
html2 ='<a href="/xinggan/21610.html" title="PartyCat轰趴猫 风骚翘臀少妇浴室性感蕾丝内衣摄影图片" target="_blank"><img src="https://xintu.crmvscrm.com/d/file/t/20201130/10/4ai2bpnkhlk.jpg" data-original="https://xintu.crmvscrm.com/d/file/t/20201130/10/4ai2bpnkhlk.jpg" alt="PartyCat轰趴猫 风骚翘臀少妇浴室性感蕾丝内衣摄影图片" style="display: inline;"></a>'
print(re.findall(pattern2,html2))
a = 'https://ss0.bdstatic.com/70cFvHSh_Q1YnxGkpoWK1HF6hhy/it/u=3075027813,1435505077&amp;fm=26&amp;gp=0.jpg'
b = a.split('/')
print(b[3])
mm = '/search/index?ct=201326592&amp;'
print(mm[17:30])
# Out:
# ['/tag/qiaotun/index_2.html']
# ['https://xintu.crmvscrm.com/d/file/t/20201130/10/4ai2bpnkhlk.jpg']
# 70cFvHSh_Q1YnxGkpoWK1HF6hhy
# 201326592&amp

# %%
import re
html ='<a href="?classid=9&amp;page=2" data="p-2" title="第2页">2</a>'
pattern = r'href="([^"]*page=[0-9]{0,2})"[^>]*>.+?' # 匹配href # 匹配href
alllinks = re.findall(pattern,html)

print(alllinks)
html2 = '<a href="/pn.x?stype=pic&amp;id=185838"　<font color="#808080">12-22</font></span></a>'
pattern2 = r'href="([^"]*id=[0-9]{2,10})"[^>]*>.+?' # 匹配href # 匹配href
alllinks2 = re.findall(pattern2,html2)
print(alllinks2)

html3 ='<img style="cursor:pointer;"  src="https://tutu.94zzh.com/d8/4091/409199-1.jpg">'
pattern3 = r'src="([^"]*[0-9]{1,5}/[0-9]{2,7}-[0-9]{1,2}.jpg)"' # 匹配href # 匹配href
alllinks3 = re.findall(pattern3,html3)
print(alllinks3)
# Out:
# ['?classid=9&amp;page=2']
# ['/pn.x?stype=pic&amp;id=185838']
# ['https://tutu.94zzh.com/d8/4091/409199-1.jpg']
