# %% [markdown]
# ### KNN-鸢尾花分类2

# %%
import numpy as np
import matplotlib.pylab as pyb
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
from sklearn import datasets

# %%
X,Y = datasets.load_iris(True)
# 4个属性 ，4 维空间 4维数据
# 150 代表样本数量   
X.shape
# Out:
# (150, 4)

# %%
# 进行降维处理  切片处理
X = X[:,:2] # 使用前两个数据
X.shape
# 测试数据
# Out:
# (150, 2)

# %%
# 画图
pyb.scatter(X[:,0],X[:,1],c=Y)

# %%
#训练
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X,Y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
# 获取测试数据
# 横坐标宽度4 ----- 8  纵坐标 2 ---- 4.5
# 背景点，取出来 调用meshgrid
x1 = np.linspace(4,8,100)
y1 = np.linspace(2,4.5,80)
X1,Y1 = np.meshgrid(x1,y1)
display(X1.shape,Y1.shape)

X1 = X1.reshape(-1,1)
Y1 = Y1.reshape(-1,1)
# X_test = np.concatenate([X1,X2],axis =1)
# ravel 将多维展平
X_test = np.c_[X1.ravel(),Y1.ravel()]
X_test.shape
# Out:
# (80, 100)
# (80, 100)
# (8000, 2)

# %%
# %%time
y_ = knn.predict(X_test)
y_.shape
# Out:
# Wall time: 193 ms
# (8000,)

# %%
# 画图
from matplotlib.colors import ListedColormap
# 定义绘图MAP 颜色
lc = ListedColormap(colors=['#FFAAAA','#AAFFAA','#AAAAFF'])
lc2 = ListedColormap(['#FF0000','#00FF00','#0000FF'])
# draw base map
pyb.scatter(X_test[:,0],X_test[:,1],c=y_,cmap=lc)
# draw fit data map
pyb.scatter(X[0:,0],X[:,1],c=Y,cmap=lc2)
# Out:
# Wall time: 28.4 ms

# %%
y_.reshape(80,100)
y_.shape
# Out:
# (8000,)

# %%
# use other to draw
pyb.contourf(X1,Y1,y_,cmap = lc)
pyb.scatter(X[0:,0],X[:,1],c=Y,cmap=lc2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-94a398d23a79> in <module>
#       1 # use other to draw
# ----> 2 pyb.contourf(X1,Y1,y_,cmap = lc)
#       3 pyb.scatter(X[0:,0],X[:,1],c=Y,cmap=lc2)
#
# d:\work-idea\python-3.8.1\lib\site-packages\matplotlib\pyplot.py in contourf(data, *args, **kwargs)
#    2520 @docstring.copy(Axes.contourf)
#    2521 def contourf(*args, data=None, **kwargs):
# -> 2522     __ret = gca().contourf(
#    2523         *args, **({"data": data} if data is not None else {}),
#    2524         **kwargs)
#
# d:\work-idea\python-3.8.1\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# d:\work-idea\python-3.8.1\lib\site-packages\matplotlib\axes\_axes.py in contourf(self, *args, **kwargs)
#    6428     def contourf(self, *args, **kwargs):
#    6429         kwargs['filled'] = True
# -> 6430         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6431         self.autoscale_view()
#    6432         return contours
#
# d:\work-idea\python-3.8.1\lib\site-packages\matplotlib\contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     853         self._transform = kwargs.pop('transform', None)
#     854
# --> 855         kwargs = self._process_args(*args, **kwargs)
#     856         self._process_levels()
#     857
#
# d:\work-idea\python-3.8.1\lib\site-packages\matplotlib\contour.py in _process_args(self, *args, **kwargs)
#    1454                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1455
# -> 1456             x, y, z = self._contour_args(args, kwargs)
#    1457
#    1458             _mask = ma.getmask(z)
#
# d:\work-idea\python-3.8.1\lib\site-packages\matplotlib\contour.py in _contour_args(self, args, kwargs)
#    1512             args = args[1:]
#    1513         elif Nargs <= 4:
# -> 1514             x, y, z = self._check_xyz(args[:3], kwargs)
#    1515             args = args[3:]
#    1516         else:
#
# d:\work-idea\python-3.8.1\lib\site-packages\matplotlib\contour.py in _check_xyz(self, args, kwargs)
#    1547
#    1548         if z.ndim != 2:
# -> 1549             raise TypeError("Input z must be a 2D array.")
#    1550         elif z.shape[0] < 2 or z.shape[1] < 2:
#    1551             raise TypeError("Input z must be at least a 2x2 array.")
#
# TypeError: Input z must be a 2D array.
